# %% [markdown]
# <a href="https://colab.research.google.com/github/David-Hien/Unit-1/blob/main/David_Aug_30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input())
b = int(input())
c = int(input())
if a >= b and a >= c:
  print(a)
  if b >= c:
    print(b, c, sep = "\n")
  else:
    print(c, b, sep = "\n")
elif b > a and b >= c:
  print(b)
  if a >= c:
    print(a, c, sep = "\n")
  else:
    print(c, a, sep = "\n")
else:
  print(c)
  if a >= b:
    print(a, b, sep = "\n")
  else:
    print(b, a, sep = "\n")

# %%
salary = int(input())
if salary <= 10000:
  print("5%")
elif salary > 10000 and salary <= 50000:
  print("10%")
elif salary > 50000 and salary <= 100000:
  print("15%")
else:
  print("25%")

# %%
a = input()
b = input()
c = input()
if a <= b and a <= c:
  print(a)
  if b <= c:
    print(b, c, sep = "\n")
  else:
    print(c, b, sep = "\n")
elif b < a and b <= c:
  print(b)
  if a <= c:
    print(a, c, sep = "\n")
  else:
    print(c, a, sep = "\n")
else:
  print(c)
  if a <= b:
    print(a, b, sep = "\n")
  else:
    print(b, a, sep = "\n")
# Out:
# Michael
# David
# Ruben
# David
# Michael
# Ruben

# %%
n = int(input("# of scores (between 4 - 5): "))
if n == 4:
  a = int(input())
  b = int(input())
  c = int(input())
  d = int(input())

  if a <= b and a <= c and a <= d:
    if b <= c and b <= d:
      lower_median = b
      if c <= d:
        upper_median = c
      else:
        upper_median = d
    elif c <= b and c <= d:
      lower_median = c
      if b <= d:
        upper_median = b
      else:
        upper_median = d
    else:
      lower_median = d
      if b <= c:
        upper_median = b
      else:
        upper_median = c

  if b <= a and b <= c and b <= d:
    if a <= c and a <= d:
      lower_median = a
      if c <= d:
        upper_median = c
      else:
        upper_median = d
    elif c <= a and c <= d:
      lower_median = c
      if a <= d:
        upper_median = a
      else:
        upper_median = d
    else:
      lower_median = d
      if a <= c:
        upper_median = a
      else:
        upper_median = c

  if c <= a and c <= b and c <= d:
    if a <= b and a <= d:
      lower_median = a
      if b <= d:
        upper_median = b
      else:
        upper_median = d
    elif b <= a and b <= d:
      lower_median = b
      if a <= d:
        upper_median = a
      else:
        upper_median = d
    else:
      lower_median = d
      if a <= b:
        upper_median = a
      else:
        upper_median = b

  if d <= b and d <= c and d <= a:
    if b <= c and b <= a:
      lower_median = b
      if c <= a:
        upper_median = c
      else:
        upper_median = a
    elif c <= b and c <= a:
      lower_median = c
      if b <= a:
        upper_median = b
      else:
        upper_median = a
    else:
      lower_median = a
      if b <= c:
        upper_median = b
      else:
        upper_median = c

  print((lower_median + upper_median)/2)

else:
  a = int(input())
  b = int(input())
  c = int(input())
  d = int(input())
  e = int(input())

  if a <= b and a <= c and a <= d and a <= e:
    if b <= c and b <= d and b <= e:
      if c <= d and c <= e:
        median = c
      elif d <= c and d <= e:
        median = d
      else:
        median = e
    elif c <= b and c <= d and c <= e:
      if b <= d and b <= e:
        median = b
      elif d <= b and d <= e:
        median = d
      else:
        median = e
    elif d <= b and d <= c and d <= e:
      if b <= c and b <= e:
        median = b
      elif c <= b and c <= e:
        median = c
      else:
        median = e
    else:
      if b <= c and b <= d:
        median = b
      elif c <= b and c <= d:
        median = c
      else:
        median = d

  if b <= a and b <= c and b <= d and b <= e:
    if a <= c and a <= d and a <= e:
      if c <= d and c <= e:
        median = c
      elif d <= c and d <= e:
        median = d
      else:
        median = e
    elif c <= a and c <= d and c <= e:
      if a <= d and b <= e:
        median = a
      elif d <= a and d <= e:
        median = d
      else:
        median = e
    elif d <= a and d <= c and d <= e:
      if a <= c and a <= e:
        median = a
      elif c <= a and c <= e:
        median = c
      else:
        median = e
    else:
      if a <= c and a <= d:
        median = a
      elif c <= a and c <= d:
        median = c
      else:
        median = d

  if c <= b and c <= a and c <= d and c <= e:
    if b <= a and b <= d and b <= e:
      if a <= d and a <= e:
        median = a
      elif d <= a and d <= e:
        median = d
      else:
        median = e
    elif a <= b and a <= d and a <= e:
      if b <= d and b <= e:
        median = b
      elif d <= b and d <= e:
        median = d
      else:
        median = e
    elif d <= b and d <= a and d <= e:
      if b <= a and b <= e:
        median = b
      elif a <= b and a <= e:
        median = a
      else:
        median = e
    else:
      if b <= a and b <= d:
        median = b
      elif a <= b and a <= d:
        median = a
      else:
        median = d

  if d <= b and d <= c and d <= a and d <= e:
    if b <= c and b <= a and b <= e:
      if c <= a and c <= e:
        median = c
      elif a <= c and a <= e:
        median = a
      else:
        median = e
    elif c <= b and c <= a and c <= e:
      if b <= a and b <= e:
        median = b
      elif a <= b and a <= e:
        median = a
      else:
        median = e
    elif a <= b and a <= c and a <= e:
      if b <= c and b <= e:
        median = b
      elif c <= b and c <= e:
        median = c
      else:
        median = e
    else:
      if b <= c and b <= d:
        median = b
      elif c <= b and c <= a:
        median = c
      else:
        median = a

  if e <= b and e <= c and e <= d and e <= a:
    if b <= c and b <= d and b <= a:
      if c <= d and c <= a:
        median = c
      elif d <= c and d <= a:
        median = d
      else:
        median = a
    elif c <= b and c <= d and c <= a:
      if b <= d and b <= a:
        median = b
      elif d <= b and d <= a:
        median = d
      else:
        median = a
    elif d <= b and d <= c and d <= a:
      if b <= c and b <= a:
        median = b
      elif c <= b and c <= a:
        median = c
      else:
        median = a
    else:
      if b <= c and b <= d:
        median = b
      elif c <= b and c <= d:
        median = c
      else:
        median = d
  print(median)
# Out:
# # of scores (between 4 - 5): 5
# 50
# 20
# 40
# 10
# 30
# 30
